# %%
import pylab
import random
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import io
from PIL import Image
import pandas

# %%
def crop_image(img):
    img_array = np.array(img)

    # Find the bounding box of non-white pixels
    rows = np.where(np.any(img_array != 255, axis=1))[0]
    cols = np.where(np.any(img_array != 255, axis=0))[0]

    if rows.size == 0 or cols.size == 0:
        return img  # No non-white pixels found

    # Crop the image to the bounding box
    cropped_img = img.crop((cols[0] - 5, rows[0] - 5, cols[-1] + 6, rows[-1] + 6))
    return cropped_img

# %%
# plt.rcParams.update({
#     "text.usetex": False,  # Ensure Matplotlib does NOT use external LaTeX
#     "mathtext.fontset": "cm",  # Use Computer Modern font
#     "font.family": "serif",
#     "font.serif": ["Computer Modern Roman"]
# })

def gen_image(tex_formula):
    fig, ax = plt.subplots()
    ax.text(0.5, 0.5, f"${tex_formula}$", fontsize=20, ha='center', va='center')
    ax.axis('off')  # Hide axes

    # Save the figure to a BytesIO object
    buf = io.BytesIO()
    plt.savefig(buf, format='png', bbox_inches='tight', pad_inches=0.2, dpi=300)
    plt.close(fig)
    buf.seek(0)
    image = Image.open(buf)

    return image

# %%
label_csv = pandas.read_csv('labels.csv')
chars = [x for x in label_csv['0']]
chars.
# Out:
# ['b',
#  'V',
#  'd',
#  '\\overline',
#  'n',
#  'a',
#  'u',
#  'p',
#  'C',
#  '+',
#  ')',
#  '<',
#  'q',
#  'x',
#  '5',
#  '(',
#  '\\infty',
#  '\\int',
#  '/',
#  '\\prod',
#  '\\pi',
#  '\\gamma',
#  '1',
#  'f',
#  '\\mu',
#  '\\theta',
#  'D',
#  'A',
#  '-',
#  '\\frac',
#  'c',
#  'h',
#  'v',
#  '=',
#  '\\approx',
#  '0',
#  'e',
#  'k',
#  '\\iff',
#  '\\sqrt',
#  '\\tilde',
#  's',
#  'L',
#  'i',
#  'M',
#  '\\hat',
#  ',',
#  '\\sum',
#  'j',
#  'z',
#  'S',
#  '\\pm',
#  '2',
#  'm',
#  '\\rho',
#  'N',
#  'y',
#  '8',
#  '\\cdot',
#  'l',
#  '.',
#  'r',
#  '\\equiv',
#  '\\forall',
#  '\\times',
#  'T',
#  '\\notin',
#  'P',
#  'w',
#  'o',
#  'G',
#  '\\rightarrow',
#  'I',
#  'E',
#  'B',
#  '3',
#  '\\nu',
#  '\\xi',
#  '6',
#  '4',
#  '7',
#  '\\partial',
#  '|',
#  '\\prime',
#  '\\eta',
#  'X',
#  '\\alpha',
#  'U',
#  '\\sigma',
#  ']',
#  '[',
#  'g',
#  '\\Gamma',
#  '\\Delta',
#  '\\simeq',
#  '\\nabla',
#  '\\vec',
#  '\\tau',
#  'R',
#  'F',
# ...

# %%
def brac_var(a):
    return '{' + a + '}'

def brac_equa(a):
    return '(' + a + ')'

def sum(a, b):
    return a + '+' + b

def sub(a, b):
    return a + '-' + b

def mul(a, b):
    return a + '\\times' + b

def div(a, b):
    return a + '\\div' + b

def fraction(a, b):
    return '\\frac{' + a + '}{' + b + '}'

def square_root(a):
    return '\\sqrt{' + a + '}'

def exp(a, b):
    return a + '^' + b

def underline(a):
    return '\\underline{}' + a

def overline(a):
    return '\\overline{}' + a

functions = [sum, sub, mul, div, fraction, square_root, exp, underline, overline]
paras = [2, 2, 2, 2, 2, 1, 2, 1, 1]
probs = [0.16, 0.16, 0.16, 0.16, 0.16, 0.1, 0.1]

lenf = len(functions)
lenc = len(chars)

def gen_formula():
    last_formula, last_fun = None, None
    numv = 5
    vars = random.choices(chars, k = numv)
    while len(vars) > 1:
        x = random.choices(vars, k = 1)[0]
        f = random.choices(functions, weights = probs, k = 1)[0]
        vars.remove(x)
        if f == square_root:
            last_formula = [x]
            last_fun = f
            vars.append(f(brac_var(x)))
            continue
        y = random.choices(vars, k = 1)[0]
        vars.remove(y)
        last_formula = [x, y]
        last_fun = f
        vars.append(f(brac_var(x), brac_var(y)))

    return (vars[0], (last_formula, last_fun))

# %%
import warnings
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

def gen_test():
    input, output = gen_formula()
    img = gen_image(input)
    img = crop_image(img)
    return img, input, output

for _ in range(10):
    img, label, output = gen_test()
    display(img)
    print(label, output)
# Out:
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern Roman
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 11
#       8     return img, input, output
#      10 for _ in range(10):
# ---> 11     img, label, output = gen_test()
#      12     display(img)
#      13     print(label, output)
#
# Cell In[28], line 6, in gen_test()
#       4 def gen_test():
#       5     input, output = gen_formula()
# ----> 6     img = gen_image(input)
#       7     img = crop_image(img)
#       8     return img, input, output
#
# Cell In[19], line 15, in gen_image(tex_formula)
#      13 # Save the figure to a BytesIO object
#      14 buf = io.BytesIO()
# ---> 15 plt.savefig(buf, format='png', bbox_inches='tight', pad_inches=0.2, dpi=300)
#      16 plt.close(fig)
#      17 buf.seek(0)
#
# ...
